# %%
#  d_system_1 작업

root = '../../dataset/wav/'

select_path = '_d_system_1/'

file_name = 'segment_'

# 손 드세요
select_file_label_0 = ['24',
                       '49',
                       '60',
                       '61',
                       '77',
                       '115',
                       '150',
                       '204',
                       '246',
                       '327',
                    #    '372',
                       '620',
                    #    '628',
                       '666',
                       '688',
                       '707',
                       '716',
                       '766',
                       '768',
                       '807'
                       ] # 18개

# 손 내리세요
select_file_label_1 = ['34',
                       '46',
                       '48',
                       '67',
                       '91',
                       '134',
                       '171',
                       '223',
                       '309',
                       '366',
                       '385',
                       '418',
                       '428',
                       '476',
                       '492',
                       '550',
                    #    '574',
                       '594',
                       '610',
                       '626',
                       '651',
                       '674',
                       '679',
                       '698',
                       '711',
                       '723',
                    #    '789'
                        ] # 25 개

# 나머지
select_file_label_2 = [
                        '26',
                        '28',
                        '30',
                        '31',
                        '37',
                        '38',
                        '40',
                        '41',
                        '43',
                        '44',
                        '100',
                        '103',
                        '110',  
                        '400',
                        '401',
                        '402',
                        '403',
                        '404',
                        '405',
                        '406',
                        '500',
                        '505', # 22개
]

# %%
stack_data = []
sum_data = []
data_block={}

for i in select_file_label_0:
    wav_path = root + select_path + file_name + i + '.wav'
    labels = '0'
    data_block = {"wav" : wav_path,
                  "labels" : labels                  
                  }
    sum_data.append(data_block)

for i in select_file_label_1:
    wav_path = root + select_path + file_name + i + '.wav'
    labels = '1'
    data_block = {"wav" : wav_path,
                  "labels" : labels                  
                  }
    sum_data.append(data_block)

for i in select_file_label_2:
    wav_path = root + select_path + file_name + i + '.wav'
    labels = '2'
    data_block = {"wav" : wav_path,
                  "labels" : labels                  
                  }
    sum_data.append(data_block)
    
data = {'data' : sum_data}

# %%
import json
with open('./choi_train.json', 'w', encoding='utf-8') as f:
    json.dump(data, f, indent=4)
