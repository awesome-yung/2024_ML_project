# %% [markdown]
# ### file 제작

# %%
root = '../dataset/wav/_2022_04_20/'

audio_list = ['segment_1.wav',
              'segment_2.wav',
              'segment_119.wav',
              'segment_121.wav',
              'segment_226.wav',
              'segment_256.wav',
              'segment_329.wav',
              'segment_417.wav',
              'segment_461.wav',
              'segment_542.wav',  #10
              'segment_545.wav',
              'segment_546.wav',
              'segment_695.wav',
              'segment_24.wav',
              'segment_26.wav',
              'segment_28.wav',
              'segment_38.wav',
              'segment_41.wav',
              'segment_46.wav',
              'segment_48.wav',  #20
              'segment_49.wav',
              'segment_57.wav',
              'segment_58.wav',
              'segment_63.wav',
              'segment_64.wav',
              'segment_67.wav',
              'segment_70.wav',
              'segment_71.wav',
              'segment_72.wav',
              'segment_77.wav',  #30
              'segment_78.wav',
              'segment_85.wav',
              'segment_87.wav',
              'segment_90.wav',
              'segment_92.wav',
              'segment_93.wav',
              'segment_97.wav',
              'segment_100.wav',
              'segment_105.wav',
              'segment_112.wav',  #40
              'segment_115.wav',
              'segment_132.wav',
              'segment_137.wav',
              'segment_144.wav',
              'segment_147.wav',
              'segment_148.wav',
              'segment_151.wav',
              'segment_153.wav',
              'segment_155.wav',
              'segment_156.wav',  #50
              'segment_163.wav',
              'segment_168.wav',
              'segment_174.wav',
              'segment_181.wav',
              'segment_184.wav',
              'segment_189.wav',
              'segment_191.wav',
              'segment_194.wav',
              'segment_195.wav',
              'segment_198.wav',#60
              'segment_199.wav',
              'segment_201.wav',
              'segment_206.wav',
              'segment_209.wav',
              'segment_210.wav',
              'segment_212.wav',
              'segment_218.wav',
              'segment_222.wav',
              'segment_225.wav',
              'segment_230.wav', #70
              'segment_232.wav',
              'segment_239.wav',
              'segment_260.wav',
              'segment_262.wav',
              'segment_266.wav',
              'segment_268.wav',
              'segment_271.wav',
              'segment_275.wav',
              'segment_283.wav',
              'segment_284.wav', #80
              'segment_293.wav',
              'segment_295.wav',
              'segment_301.wav',
              'segment_306.wav',
              'segment_310.wav',
              'segment_315.wav',
              'segment_318.wav',
              'segment_323.wav',
              'segment_325.wav',
              'segment_332.wav',#90
              'segment_336.wav',
              'segment_337.wav',
              'segment_340.wav',
              'segment_342.wav',
              'segment_348.wav',
              'segment_350.wav',
              'segment_354.wav',
              'segment_355.wav',
              'segment_359.wav',
              'segment_365.wav', #100
              ]

text_list = ['명령어가 같은 레지스터에 라이트 하는 경우 이 순서도 유지해줘야된다.',
             '이 전에 라이트가 먼저 일어나고',
              '여기까지 다 이해되죠 이해되죠 이해 된 사람 손들어보세요',
              '쭉 한번 손 들어보세요',
              '자 이 슬라이드 다 이해됩니까 이해된 사람 손들어보세요 이해 안된',
              '자 이해한 사람 손 들어보세요',
              '된 사람 손 들어보세요 그래서 여러분',
              '김태현 학생이 설명한 거랑 내가 설명한 거랑 이해되는 사람 손 들어보세요',
              '이해한 사람 손들어보세요',
              '여기 지금 설명 이해되요 이해된 사람 손 들어보세요', # 10
              '오십오명 조금 더 많네 자 더 손들어보세요 적극적으로 오십 칠 육십',
              '채워봅시다 손 손 손 이해된사람 손',
              '오케이 이해 된 사람 손 들어보세요',
              '안되기 떄문에 우리가 엔타입 디펜던시라고 부르고 이거 역시',
              '가 될수도 있습니다 여기까지 다 이해하죠',
              '여것만 트루 디펜던스고 나머지 두가지를 우리가 폴스 디펜던스라고',
              '이 엔타입 디펜던스 역시 다 아 해결을 해줄수가 있습니다 그래서',
              '어 이 레지스터를 공유하기 때문에 스토리지를 공유',
              '그래서 여러분이 사용하는 아이세븐이나',
              '같은 경우 현재 다 아웃오브오더 어 파이프라인으로 되어있고 이 경우에', # 20
              '실질적으로 여러분한테는 소개하지 않 하드웨어 레지스터',
              '그 하드웨어 레지스터 리네이밍에 대해서는 이 강의에서는 이야기하지 않고 궁금한',
              '대학원 수업을 대학원에 와서 들으면 이해할 수 있을거고',
              '내용이에요 그 다음에 지금까지는 이제 그 레지스터 ',
              '에 대해서만 얘기했는데 이러한 데이터 디펜던스는 메모리 로케이션에 대해서도',
              '메모리 로케이션 비에다가 스토어하면 얘가 라이트가 되는거고 다시',
              '이 앞의 스토어가 메모리 로케이션에 쓴 다음에 읽어야되니까 여기도 역시',
              '메모리 로케이션 비에 대해서 리드 애프터 라이트 디펜던스가 발생할 수 있고 마찬가지로',
              '뭐 같은 스토어 에이 스토어 에이가 일어나는 경우',
              '질문 있으면 질문해줘요 그래서 지금 얘기한 디펜던스는', # 30
              '머신의 특성이 아니라 프로그램이 갖고 있는 속성이에요 프로그램에 있',
              '전에 다음 명령어들이 실행되면서 오버랩돼서 실행되기 때문에',
              '깨지고 실제 프로그램 결과가 잘못된 추적을 가져올 수 있다',
              '반드시 만족되어져야 한다 알겠죠 여러분',
              '어',
              '그거를 회피할 수 있는 방법도 있어요 레지스터랑은',
              '에',
              '어 지금 이야기할 파이브 스테이지 파이프라인에서 이런 디펜던스를 만족하기 위해서는',
              '읽어서 알 쓰리에다가 라이트 한거에요 그래서 지금 첫번쨰 명령 알 원',
              '자 이거는 다 이해해야되요 뭐 이거는 너무 쉬우니까 여러분이 다 이해를 하는걸로 생각', # 40
              '는서 존재한다 그쳐 그다음에',
              '데스티네이션만 보면 되는데 여기서 데스티네이션이 같은게 일 이 삼 사 삼',
              '알 쓰리에 대해서 사번 명령어가 리드를 하고 오번 명령어가 라이트를 하죠',
              '라이트애프터리드 디펜던스가 존재한다 이렇게 크흠 표',
              '자 이렇게 프로그램 디펜던스를 이제 프로그램 안에서 나열할 수 있고',
              '이거를 파이브 스테이지 파이프라인을 가지고 이 디펜던스를 만족하면서 파',
              '로드가 페치돼서 디코드되고 그 다음에 뭐',
              '알 원에 라이트를 하는거에요 그쳐 그 다음에 마찬가지로',
              '실행을 마치면 어 그다음에 얘가 실행에 들어가서 엑스큐션하고',
              '라이트백 두 명령어 사이의 디펜던스는 없습니까',  # 50
              '동안 어 세번째 명령어 리드 스테이지에서 멈추',
              '리사이클 되는 것을 스톨이라고 합니다 그래서 투 사이클에 스톨이 발생하는거고',
              '오케이 그러면 인제 알 원을 이때 쓰고 알 투가 여기 쓴 다',
              '페치말고 이 파이프라인이 어떻게 되어 있냐면 페',
              '얘를 프론트엔드라고도 얘기할 수 있는데 앞의 명령어가 리드 스테이지에서 멈추고 있으면',
              '디 디코드 진유석 학생 하니씩만 있어요',
              '명령어만 페치되게 두면 두 번째 사이클에서 다섯 사이클이 되면은',
              '김윤수 학생 이해되죠',
              '다들 이해했죠 메모리로', # 60
              '리드 알때는 기다리기만 하는건가요 세번째 여기서',
              '레지스터파일에서 이 스테이지에서 읽을수가 없어요 왜냐 쓰고 있는 중이라 아직',
              '그러니까 알 원 알 투 둘다 읽을려면 투 사이클 리사이클하다가 스톨하다',
              '둘다 읽어야되는거니까 어 처음에는 알 원 알',
              '알 원 알 투 다 읽는거죠 다 따라오죠',
              '그 다음에 이제 요게 이제 애드 명령인데 애드 명령이 결국 엑스큐션',
              '알 원 알 포를 읽어야되는데 여기서는 읽을수가 없으니까 투 사이클동안 스토어',
              '어 프로그램이 실행이 딜레이가 되는 겁니다 다들 이해하죠 이제',
              '어블 리드 애프터 라이트 디팬던트 즉 데이타의',
              '이제 실행시간은 이만큼 딜레이가 생긴겁니다.',  # 70
              '스톨은 파이프라인에',
              '디펜던스를 체크한 다음에 리드 스테이지에 있는 명령어를 진행을 안시키고',
              '이송아 학생 맨 밑에 에이사이클 딜레이 있는거 한번만',
              '모르는 학생은 질문 부끄러워하지말고',
              '질문해줘요 오케이 다들 이해했죠 지금 오십구명 육십명이라 ',
              '를 쫌 달리했어요 그래서 멀티플라이에 실행은 한 싸',
              '어 실제 벡엔드의 멀티플라이어랑 에더',
              '페치 디코드 리드가 있고 로드는 한 사이클 걸리는데 ',
              '파이프라인 혹은 펑셔널 유닛',
              '인스트럭션 파이프라인은 순차적으로 프로그램 순서대로 들어간 다음에 명령어 타입엔', # 80
              '에 따라 로드나 스토어면 일로 보내지고 덧셈 뺄셈을 일로 보내주고',
              '쪼끔 코드를 바꿨어요 그래서 앞에는 여기 디펜던스가 멀티플라이랑 엑스 사이에 존재하는데',
              '그쵸 얘는 알 파이브랑 알 식스인데 이전 명령어에 사이즈 디펜던스가',
              '가 먼저 끝날 수가 있어요 그래서 실제 끝날 때는 일반적인 ',
              '서브트랙트 명령이 여기 페치 스테이지에서 스톨 하다가 이거를 아무렇게나',
              '알 원은 이때 어밸러블 하고 알 포는 이때 어밸러블해요',
              '스톨은 라이트 애프터 라이트 디펜던스 때문에 여기서 멈춰진거에요 왜냐',
              '발생하니까 지금 라이트 애프터 라이트 바일',
              '두 디펜던스 다 만족해야되기 때문에 오케이',
              '여기 여기 마지막 스토어 명령인가 어 그래서 디코딩 스테이',  # 90
              '하드웨어에서 어떻게 실행되는지 파이프라인 다이어그램을 그려라하면 요거를 여러분이 그릴 수 있어야되',
              '자 그래서 파이프라인이',
              '을 구현하게 되면은 단순하게 그냥 프로그램에 있는 명',
              '적으로 만약에 디펜던스가 존재하는 경우는 그 디펜던트한 명령을',
              '프 라인 제어 메커니즘을 파이프라인 스톨이라고 하고 이거',
              '인티저 명령 같은 경우는 에이엘유는 한 사이클 걸리고 같',
              '스터파일을 공유한다고 가정하고 얘는 네 사이클 걸리고',
              '각의 소스에 대해서 여기에 그 해당하는 프로듀서가',
              '여기 데스티네이션이 있는지를',
              '여섯 일곱 여덟 아홉 열개가 요거에 대해서 스페어',  # 100
              '요 스테이지에 있는 데스티네이션 레지스터하고 요거는 그전 명령이기 때문에 요'
             ]
# '번쨰 명령 멀티플라이 명령을 보면 페치하고 디코드 할려고 하는데',

# %% [markdown]
# ### file 확인

# %%
import IPython.display
import os

select_file = 99   # n번째 파일의 text 확인, -1은 마지막 파일
audio_file_path = os.path.join(root, audio_list[select_file])
print(audio_file_path)
print(text_list[select_file])
IPython.display.Audio(audio_file_path)
# Out:
# ../dataset/wav/_2022_04_20/segment_365.wav
# 요 스테이지에 있는 데스티네이션 레지스터하고 요거는 그전 명령이기 때문에 요
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print('audio 개수 : ', len(audio_list))
print('text 개수 : ', len(text_list))
# Out:
# audio 개수 :  100
# text 개수 :  100
