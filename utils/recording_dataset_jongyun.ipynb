# %% [markdown]
# ### file 제작

# %%
root = '../dataset/wav/_2022_04_04/'

audio_list = ['segment_3.wav',
              'segment_4.wav',
              'segment_5.wav',
              'segment_8.wav',
              'segment_10.wav',
              'segment_11.wav',
              'segment_14.wav',
              'segment_15.wav',
              'segment_16.wav',
              'segment_17.wav',  #10
              'segment_18.wav',
              'segment_19.wav',
              'segment_20.wav',
              'segment_22.wav',
              'segment_23.wav',
              'segment_32.wav',
              'segment_34.wav',
              'segment_36.wav',
              'segment_37.wav',
              'segment_41.wav',  #20
              'segment_42.wav',
              'segment_43.wav',
              'segment_45.wav',
              'segment_52.wav',
              'segment_56.wav',
              'segment_59.wav',
              'segment_60.wav',
              'segment_63.wav',
              'segment_64.wav',
              'segment_65.wav',  #30
              'segment_72.wav',
              'segment_73.wav',
              'segment_74.wav',
              'segment_84.wav',
              'segment_85.wav',
              'segment_86.wav',
              'segment_87.wav',
              'segment_88.wav',
              'segment_93.wav',
              'segment_94.wav',  #40
              'segment_95.wav',
              'segment_96.wav',
              'segment_100.wav',
              'segment_101.wav',
              'segment_104.wav',
              'segment_107.wav',
              'segment_108.wav',
              'segment_109.wav',
              'segment_121.wav',
              'segment_122.wav',  #50

              ]

text_list = ['자 링커가 하는 일을 살펴 보면 어 그',
             '여러 개의 리로케이터블 오브젝트 파일들을',
             '링크, 연결해서 실행할 수 있는 하나의 실행 파일을',
             '파일 안에는 데이터도 있고 코드도 있습니다. 그래서 여러분이 다시',
             '정의돼 있고 하죠. 그래서 거기에는 코드랑 데이터가 다 포함되어 있어',
             '그래서 링커가 하는 거는 코드는 또 코드끼리 모으고 데이터는 데이',
             '그래서 또 얘가 두번째 하는 일은 익스터널 레퍼런스를 리저브하는 겁니다.',
             '이건 뭐냐 하면은 각각의 다시 파일에 보면은',
             '그 안에 정의된 함수나 그 안에 정의된 글로벌 변수도 있지만',
             '그 코드 안에는 외부에서 정의된 글로벌 변수를 참조하거나',  #10
             '또 외부에서 정의된 펑션을 참조할 수가 있어요. 그래서 각각',
             '의 리로케이터블 오브젝트 파일에 있는 익스터널 레퍼런스',
             '외부의 외부의 정의된 함수나 변수를 참조하는 익스',
             '어떤 파일에 정의된 어떤 변수 어떤 함수인지를 결정을 해야돼요',
             '그거를 이제 리저브 익스터널 레퍼런스고',
             '그 그 오브젝트 파일 안에서 이 변수가 몇번째 글로벌 변수인지 이게 어',
             '지만 익스큐터블 오브젝트 파일이 만들어 지면 실질적',
             '펑션이나 변수들이 다 포함되기 때문에 익스큐터블 오프젝트 파일',
             '안에 이제 하나 모이면 거기서 실제 그 변수나',
             '절대적 위치가 이제 결정이 되죠. 링커에 의해서 그리고',    #20
             '각각의 오브젝트 파일에 있는 익스터널 레퍼런스들 아까 얘기했던',
             '번수나 함수들을 가리키는 그 레퍼런스. 레퍼런스 그 실제는 다 거의',
             '들어가 있죠. 그 다음에 변수를 억세스할 수 있는 변수의 주손데 그 주소',
             '이 오브젝트 파일이 이제 여러 개가 있고 여기에는 펑션도 있고 어',
             '어떤 코드 안에 어떤 변수나 어떤 참조도 외부에 있는 펑선이나 외부에 있는 변수',
             '여기서 만약에 어떤 코드에서 뭐 이런 에이라는 펑션을 부르면',
             '에이는 아 뭐 이 코드 안에서 정의된',
             '이 각각의 레퍼런스 채널 레퍼런스는 펑션일 수도 있고',
             '여기서처럼 이제 데이터일 수도 있죠 레퍼런스 투 심볼 액스',
             '그래서 각 코',    #30
             '코드는 코드끼리 모아져서 이 텍스트',
             '리젼에 들어가고 데이터는 데이터끼리 모아져 모아져서 데이터 세그먼트에 들어갑니다',
             '여기서 각각의 펑션의 위치 여기 에프 뭐 지',
             '덩어리로 자르게 되면 공유하기가 어려워서 이런 조각들로 잘게',
             '되고 그래서 프로그램이 조그만 소스 파일들의 컬렉션으로',
             '어 작성을 하게 되려면 우리가 나중에 요런',
             '오브젝트 파일 로케이트 오브젝트 파일을 묶어서 하나의 라이브러리로',
             '만드는 경우에 어떤 어 펑션을 공유하',
             '프로젝트 전체를 리컴파일했어야 하는데 이제는 오브젝트 파일 하나',
             '만 컴파일하면 되고 얘만 연결시키면 되니까 컴파일 시간도 적고', #40
             '다른 소스 파일들을 컴파일할 필요가 없어지죠',
             '그 다음에 이렇게 라이브러리들을 만들 수가 있으면서도 실',
             '스페이스 면에서도 뭐 효율적이다 이런 말입니다.',
             '자 오브젝트 파일 포',
             '이건 옛날 형태고 내가 그 1900 뭐 예를 들어',
             '윈도우 얘기고 그',
             '유닉스에서는 모든 실행 파일의 이름은 에이 닷 아웃이었어요',
             '그리고 이때 에이 닷 아웃을 내가 이름을 바꿔서 어 에이 닷 아웃을 프로그램',
             '그래서 이제 유닉스 시스템 파이브를 좀 변형한 버전이고',
             '현재의 유닉스는 시스템 파이브가 사용하고 있는 코프를' #50
             ]

# %%
root = '../dataset/wav/_2022_04_06/'

audio_list = [
              'segment_1.wav',
              'segment_2.wav',
              'segment_3.wav',
              'segment_4.wav',
              'segment_5.wav',
              'segment_15.wav',
              'segment_16.wav',
              'segment_17.wav',
              'segment_18.wav',
              'segment_19.wav',  #60
              'segment_20.wav',
              'segment_21.wav',
              'segment_47.wav',
              'segment_48.wav',
              'segment_49.wav',
              'segment_50.wav',
              'segment_51.wav',
              'segment_52.wav',
              'segment_53.wav',
              'segment_54.wav',  #70
              'segment_69.wav',
              'segment_72.wav',
              'segment_73.wav',
              'segment_74.wav',
              'segment_75.wav',
              'segment_76.wav',
              'segment_111.wav',
              'segment_112.wav',
              'segment_113.wav',
              'segment_120.wav',  #80
              'segment_121.wav',
              'segment_134.wav',
              'segment_135.wav',
              'segment_138.wav',
              'segment_139.wav',
              'segment_144.wav',
              'segment_145.wav',
              'segment_146.wav',
              'segment_147.wav',
              'segment_149.wav',  #90
              'segment_151.wav',
              'segment_152.wav',
              'segment_222.wav',
              'segment_223.wav',
              'segment_224.wav',
              'segment_278.wav',
              'segment_279.wav',
              'segment_325.wav',
              'segment_326.wav',
              'segment_555.wav'  #100
              ]

text_list = [
             '줌에서 로그인이 잘 안 돼가지고 조금 늦었는데 강의 시작할게요',
             '지난 시간에 이어서 우리가',
             '링커에서 하는 그 심볼 레졸루션에 대해서 공부를',
             '어 설명을 하도록 하겠습니다',
             '여기서 얘기하는 심볼은 각 리로케이트',
             '그 외부에 있는 글로벌 변수나 외부에 있는 함수의',
             '경우는 어 조금 더 까다로워 질수가 있습니다. 먼저 지난 시간에',
             '우리가 살펴 봤듯이 링커에서는 어 이런 심볼들을',
             '크게 두 가지의 경우로 나눕니다. 스트롱 심볼은 뭐냐 하면 모든 펑션 네임이랑',
             '초기화된 글로벌 변수는 스트롱 심볼이고 그 다음에 초기값을', #60
             '갖고 있지 않은 글로벌 변수는 위크 심볼이라고 합니다.',
             '그래서 여기 이제 피원 다시 하고 피투 다시 파이를 살펴',
             '이 액스에 대해서 오퍼레이션이 이루어지면은 원하지 않은',
             '그 저 값이나 결과를 가져올 수도 있겠죠 그냥',
             '두 함수에 의해서 액스에 대한 업데이트가 인터리빙되니까',
             '그러나 이런 경우는 아 뭐 링킹 에러는 발생하지 않지만 문제가 생길 수가 있',
             '고 이런 경우는 사실은 굉장히 디버깅하기가 어려운 코드고 고쳐줘야 돼요',
             '안 그러면 코드가 원하지 않는 예상하지 않은 결과가 나올',
             '수 있습니다. 여기까지 이해하죠?',
             '오케이 그 다음', #70
             '만약에 첫번째 액스로 결정한 경우 이해 되죠 그래서 막',
             '음 오케이 그 다음에 네번째 이그잼플',
             '같은 경우 여기는 위크 심볼 여기는 스트롱 심볼 그래서 여기서 정의한 액스는',
             '무시하고 모든 여기서 액스의 참조는 첫번째',
             '파일에 있는 액스를 참조하게 됩니다. 그래서 여기서는 실수',
             '8 바이트 연산을 하면 실질적으로 무조건 액스랑 와이를 둘 다',
             '뭐 그래서 각 파일에 있는 변수, 어 글로벌 변수에',
             '대한 참조 또 펑션 네임에 대한 참조를 정확하게',
             '해당하는 데피니션으로 이제 리저브를 하죠. 리저브를 하게 되면',
             '크기가 결정이 됩니다. 알겠죠?', #80
             '그래서 어 정확하게 아이덴티파이',
             '잘 따라오고 있',
             '어요? 예 오케이',
             '그래서 여러 인풋 모듈, 모듈이란 게 파일이라 그랬죠? 오브젝트 파일에 분산',
             '되어있는 데이터 섹션들을 모아서 하나의 통합된 데이터 섹션, 또 하나의 통합',
             '데이터셋의 시작 위치 이런 게 정해지기 때문에 어',
             '여기 있는 뭐 글로벌 변수라던 지 여기 있는 펑션',
             '이나 어떤 주소 각 명령어의 주소가 모두 결정되는 거에요 그래서',
             '어 각각의 애그리게이트 섹션에서 각 심볼, 펑션이라든지 변수',
             '결정이 됩니다. 이해됩니까?', #90
             '잘 이해되죠? 오케이 그래서',
             '다음에는 이제 텍스트 세션에 보면은 여기 이제 이 텍',
             '음 그래서 여기는 이',
             '헤더 뭐 이엘에프 헤더도 있고 뭐 여러가지 헤더 파일들이 있었죠 그 다음에 요',
             '런 텍스트 데이터 비에스에스 그 다음에 뭐 여기 뭐',
             '그니까 첫번째 상대적인 오프셋 위치가 0으로 되어있는거에요.',
             '이해됩니까?',
             '그 다음에 여기는 이제 물음표가 있는 거고 물음표를 얘가 나중에',
             '에이의 주소로 바꿔 주세요 절대 주소로 바꿔 주세요 에이랑',
             '데이터 섹션. 익스큐터블 파일에 익스큐터블 파일에 있는 데이터 섹션' #100
             ]

# %% [markdown]
# ### file 확인

# %%
import IPython.display
import os

select_file = -1   # n번째 파일의 text 확인, -1은 마지막 파일
audio_file_path = os.path.join(root, audio_list[select_file])
print(text_list[select_file])
IPython.display.Audio(audio_file_path)
# Out:
# 에이의 주소로 바꿔 주세요 절대 주소로 바꿔 주세요 에이랑
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print('audio 개수 : ', len(audio_list))
print('text 개수 : ', len(text_list))
# Out:
# audio 개수 :  38
# text 개수 :  37
