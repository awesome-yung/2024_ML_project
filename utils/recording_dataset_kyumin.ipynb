# %% [markdown]
# ### file 제작

# %%
## 61개, 손드세요 없음 ##
root = '../dataset/wav/_2022_03_16/'

audio_list = ['segment_5.wav',
              'segment_7.wav',
              'segment_10.wav',
              'segment_11.wav',
              'segment_12.wav',
              'segment_13.wav',
              'segment_14.wav',
              'segment_18.wav',
              'segment_20.wav',
              'segment_21.wav', # 10개
              'segment_24.wav',
              'segment_26.wav',
              'segment_31.wav',
              'segment_32.wav',
              'segment_33.wav',
              'segment_34.wav',
              'segment_39.wav',
              'segment_41.wav',
              'segment_42.wav',
              'segment_43.wav', # 20개
              'segment_46.wav',
              'segment_48.wav',
              'segment_49.wav',
              'segment_51.wav',
              'segment_53.wav',
              'segment_54.wav',
              'segment_55.wav',
              'segment_68.wav',
              'segment_69.wav',
              'segment_73.wav', # 30개
              'segment_79.wav',
              'segment_81.wav',
              'segment_93.wav',
              'segment_99.wav',
              'segment_104.wav',
              'segment_123.wav',
              'segment_256.wav',
              'segment_286.wav',
              'segment_291.wav',
              'segment_302.wav', # 40개
              'segment_323.wav',
              'segment_325.wav',
              'segment_326.wav',
              'segment_328.wav',
              'segment_330.wav',
              'segment_332.wav',
              'segment_333.wav',
              'segment_338.wav',
              'segment_340.wav',
              'segment_342.wav', # 50개
              'segment_349.wav',
              'segment_412.wav',
              'segment_414.wav',
              'segment_417.wav',
              'segment_419.wav',
              'segment_423.wav',
              'segment_432.wav',
              'segment_435.wav',
              'segment_437.wav',
              'segment_454.wav', # 60개
              'segment_459.wav'
        
              
              
              
              ]

text_list = ['나가는 편이 있는데. 아 뭐 쭉 좀 천천',
             '아 조금 천천히 이번부터 강의를 다시 진행하도록 하겠습니다',
             '잠깐 얘기 했었는데 인텔의 프로세서들은 모두 다 인텔의 삼십',
             '이 빗 인스트럭션 셋 아키텍쳐 그래서 얘를 아이에이 서티투 인텔 아',
             '키텍쳐 32 또 보통 이거를 다른 말로 엑스 86',
             '이라고 또 부르는 그러한 인텔의 32빗',
             '인스트럭션 셋 아키텍쳐라는 머신 랭귀지를 실행하는 그러한',
             '어 모든 프로세서마다 자신만의 독특한 랭귀지를',
             '우리가 패밀리란 말을 씁니다 그래서 엑스86 패밀리',
             '혹은 암 뭐 패밀리 이런 식으로 간', # 10개
             '그런 머신랭귀지를 실행하는 그런 프로세서들이고',
             '5세대로 구분을 합니다 그래서 80386이 2세',
             '명령어로 실행하는 방법 내부구조 성능은',
             '어 세대마다 굉장히 다릅니다 그래서 그 내부구조를 우리가 다른 말로 어 마이크',
             '로 아키텍쳐 라고 합니다',
             '그래서 아이에이서티투',
             '페치서부터 디코드 그 다음에 오퍼랜드를 리드하고',
             '모든 명령어의 차례를 마친 다음에 다음 명령어의 페치를 시작하는',
             '그러한 형태로 시퀀셜 구조로 되어있는게 80386이고',
             '80486부터는 파이프라인 구조를 사용한다고 했어요. 그래서 첫 번째 명령어인', # 20개
             '파이브 사이클 파이브 스테이지가 지난 다음에는 어 그',
             '어 끝낼 수 있어서 그 처리 속도를 스테이지 수만큼 이론적으로 어 그',
             '늘릴 수 있는 그러한 형태의 구조를 파이프라인 프로세서라고 얘기합니다 요게 2세대',
             '한 번에 두 개의 명령씩 페치 디코드 리드 익스큐',
             '페치에서 실행하는 이런 프로세서를 우리가 수퍼 스케일러 프로세서라고 하고',
             '고 두 개씩 처리하니까 이거를 투 웨이 수',
             '수퍼스케일라라고 부른다고 이야기 했습니다. 그래서 486이나 3',
             '복잡성이 올라가지만, 더 커지지만 성능은 보통 한',
             '25프로에서 한 40프로까지 성능이 올라가서 같은 공정에서도',
             '이제 펜티움 포도 펜티움 프로랑 마찬가지로 쓰리', # 30개
             '은 더 줄어들고 결과적으로 요 각 한 스테이지에 한 클락 사이클이 들어가',
             '두 배로 증가시킬 수가 있겠죠 왜냐 펜티움 프로에서 10단계로 하던 거를 20단',
             '완전히 다르고 같은 공정으로 해도 뒷 세대가 좀 더 발전된 그런',
             '어 편하게 질문을 해주세요 그래서 우리 조금 진도를 천천히 나가더래도',
             '나왔으니까 미리 설명을 하면 어 이',
             '된 패쓰에서 가져온 명령어들이니깐 이 플러쉬 취소해야 돼요',
             '이 반도체 공정 기술의 발전을 보니까 아 아이씨칩에 집적할 수 있는',
             '피피티이긴 한데 여기서 뭐 에디팅하고 좀 더 많은 기능을 하려면 또 해',
             '하니까 편하게 질문을 하세요. 알겠죠?',
             '프로세스 하드웨어를 우리가 프로세서라고 하고 마이크로프로세서라', # 40개
             '데이터만 64비트로 확장된 결국 코드는 같고 데이터의 크기만 확',
             '엑스86 패밀리라고도 부르는 이유가 있습니다. 알겠죠? 음.',
             '그리고 인텔이 이제 요건 인텔 아키텍쳐 서티 투고',
             '로 만든 그 인스트럭션 셋 아키텍쳐 머신 랭귀지를 아이',
             '랭귀지고 얘는 리스크 기반이',
             '발전된 에픽이라는 뭐 인텔은 이렇게 부르는데 그러한 새로운',
             '어 그러한 인스트럭션 셋 아키텍쳐 스타일로 디파인된 언어예요 그래서 어',
             '따라서 이 독립 명령어에 그런 패럴리즘 표현되어있기 때문에 그걸 이용해서',
             '병렬 처리 할 수 있는 그거를 좀 더 편하게 할 수 있는 그러한 인스트럭션 셋 아키텍쳐',
             '는 완전히 다른 언어이고 그거의 첫 번째 세대가 아이테니움', # 50개
             '인텔이 점유하면서 선이 이제 거의 망해서 오라클이라는 회사에 흡수돼서',
             '서버 시장의 가장 대표적인 주자가 선 마이크로 시스템이에요. 선 마이크로 시스',
             '이 시장을 피씨의 CPU성능이 계속 좋아지면서 인텔',
             '이 선은 이제 오라클에 흡수되어 있습니다. 알겠죠? 아직도 대형이',
             '그래서 이제 1980년대 중반까지 약간 구',
             '우리가 어떤 거는 원 바잍, 어떤 건 투 바잍, 어떤 건 포 바잍, 어떤 건 파이브 바잍',
             '떨어 뜨린다. 불필요하게 복잡하게 설계하지 않고 어 간단간',
             '하면 되니까 이렇게 디자인한 것이 더 심플하고 실제 내부',
             '높일 수 있다하는 그러한 아 연구를 많이 하셨어요. 그래서',
             '자 워드는 뭐냐, 어떤 프로세서가 32빝이냐 8빝이냐 16빝',
             '쌓았냐를 결정하고 우리가 주소는 뭐 주소도 데이타기 때문에'
             
             
             
    
             ]

# %%
import IPython.display
import os

select_file = 60 # n번째 파일의 text 확인, -1은 마지막 파일
audio_file_path = os.path.join(root, audio_list[select_file])
print(text_list[select_file])
IPython.display.Audio(audio_file_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
root = '../dataset/wav/_2022_03_30/'

audio_list = ['segment_1.wav',
              'segment_3.wav',
              'segment_337.wav',
              'segment_338.wav',
              'segment_339.wav',
              'segment_341.wav',
              'segment_343.wav',
              'segment_345.wav',
              'segment_346.wav',
              'segment_347.wav', # 10개
              'segment_348.wav',
              'segment_349.wav',
              'segment_352.wav',
              'segment_353.wav',
              'segment_355.wav',
              'segment_359.wav',
              'segment_361.wav',
              'segment_362.wav',
              'segment_365.wav',
              'segment_368.wav', # 20개
              'segment_369.wav', 
              'segment_371.wav',
              'segment_377.wav',
              'segment_379.wav',
              'segment_380.wav',
              'segment_381.wav',
              'segment_382.wav',
              'segment_403.wav',
              'segment_433.wav',
              'segment_439.wav', # 30개
              'segment_442.wav',
              'segment_443.wav',
              'segment_492.wav',
              'segment_494.wav',
              'segment_499.wav',
              'segment_590.wav',
              'segment_657.wav',
              'segment_779.wav',
              'segment_796.wav'
            
              ]

text_list = ['이프 이그잼플이라는 간단한 프로시저를 살펴봤어요',
             '4개를 받아서 그 쥐 에이치 아이 제이 아 쥐 플러스 에이',
             '아 이해되는 사람 손 들어보세요. 카운트해 봅시다 몇 명이나 이해했는지 110명 중에서',
             '손 들어 보세요.',
             '자 열 두 명 다 손 들어봅시다. 여러분이 지금',
             '이해된다 손 들어보세요 손 들어보세요. 마흔 다섯 명?',
             '있을 거예요. 어. 50명. 51 계속 찾아보세요.',
             '61. 음. 62. 64. 50',
             '65. 다 한 번 들어보 저 70',
             '69명. 어 여기 질문이 또 나오네. 아직 이해못한 학생들도 있을 테니까.', # 10개
             '72. 여기서 한 반 이상이 이해하고 있는거 같애요. 계속 손 들고 있으세',
             '세요. 이해되는 사람은 손 들어보세요 그래서. 어 김희진 학생이 질문에 대답해봅시다.',
             '각 펑션 인보케이션마다 자신의 아규먼트하고 자',
             '자신의 리턴 어드레스는 자신의 스택 프레임에 저장해놨죠. 그래서 다른 펑션',
             '서 자기의 아규먼트하고 자신의 리턴 어드레스를 복구하는 일이에요.',
             '다 위치가 다른 건',
             '들어가 있었고. 팩트 투는 팩트 다시하고 2가 들어가 있을 거고. 팩트 원은 팩트',
             '다시하고 1이 들어가 있었죠. 김희진 학생 이제 이해돼요?',
             '값이 1로 변하는게 맞나요?',
             '1 콜하기 위해서 요때 팩트 1의 아규먼트인 에이 제로를 1로', # 20개
             '로 바꿔놓은 거예요. 팩트 1을 콜하기 전에. 손명준 학생 이해되죠?',
             '손명준 학생 따라왔어요?',
             '레지스타 에이제로는 다 공유하고 있는데, 자신이 처음 받은 아규먼트',
             '때 에이 제로를 사용해야 되기 때문에 얘를 요기 2에다가 요기다가',
             '저장해놓고 욜로 가서 패 에이 제로를 1로 한 다음에 팩트',
             '1을 콜한거야. 아규먼트 레지스터를 바꾼 다음에만 팩토리알',
             '콜을 할 수 있기 때문에. 손명준 학생 이해되죠? 같은 에이제',
             '저 이해한 학생은 75명인데 다 이해한 학생 다 한 번 더 손 들어보세요',
             '다 100프로는 아니네. 더 이해한 사람 손 들어보세요',
             '어 오케이. 최성호 학생. 각자의 스택 프레임에 저장된 에이 값과',
             '여기 이거는 메모리 메모리에 있는 거고',
             '에이 제로 이거는 레지스타에요 레지스타',
             '프로그램을 큰 덩어리 하나로 짜게 되면 나중에 보니까 요거 뭐',
             '프로그램이 커지면 컴파일 하는 데 시간이 오래 걸리죠. 전체를 다시',
             '하고자 하는 펑션을 쉐어할 때 불편해집니다.',
             '오케이. 그 다음에 마이너스 오는',
             '이 라이브러리라는 것은 뭐냐면 뒤에서 배우겠지만 오브젝트 파일 아까 릴로케이터블 오브제',
             '스태틱 링커만 생각하면 얘가 그 조각들을 모두 연결해서',
             '게 아니라 런타임에 링킹되게 돼있어요 그래서 실제 여기있는 오브제'
             
             ]

# %% [markdown]
# ### file 확인

# %%
import IPython.display
import os

select_file = 38  # n번째 파일의 text 확인, -1은 마지막 파일
audio_file_path = os.path.join(root, audio_list[select_file])
print(text_list[select_file])
IPython.display.Audio(audio_file_path)
# Out:
# 펑션들은 실질적으로 컴파일러에 스태틱하게 링킹된
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print('audio 개수 : ', len(audio_list))
print('text 개수 : ', len(text_list))
# Out:
# audio 개수 :  6
# text 개수 :  6
