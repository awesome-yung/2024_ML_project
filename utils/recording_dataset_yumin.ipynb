# %% [markdown]
# ### file 제작

# %%
root = '../dataset/wav/_d_system_1/'

audio_list = ['segment_5.wav',
              'segment_10.wav',
              'segment_15.wav',
              'segment_20.wav',
              'segment_24.wav',
              'segment_25.wav',
              'segment_30.wav',
              'segment_40.wav',
              'segment_46.wav',
              'segment_48.wav',
              'segment_49.wav',
              'segment_59.wav',
              'segment_60.wav',
              'segment_65.wav',
              'segment_66.wav',
              'segment_67.wav',
              'segment_79.wav',
              'segment_80.wav',
              'segment_81.wav',
              'segment_85.wav',
              'segment_100.wav',
              'segment_105.wav',
              'segment_110.wav',
              'segment_114.wav',
              'segment_115.wav',
              'segment_118.wav',
              'segment_132.wav',
              'segment_134.wav',
              'segment_137.wav',
              'segment_200.wav',
              'segment_201.wav',
              'segment_202.wav',
              'segment_203.wav',
              'segment_204.wav',
              'segment_220.wav',
              'segment_240.wav',
              'segment_350.wav',
              'segment_352.wav',
              'segment_365.wav',
              'segment_400.wav',
              'segment_455.wav',
              'segment_478.wav',
              'segment_490.wav',
              'segment_495.wav',
              'segment_706.wav',
              'segment_707.wav',
              ]

text_list = ['와이가 들어왔을 때 엑스가 일이고 와이가 영이거나',
             '같을 같을 때 일을 출력하는 거예요. 그래서',
             '엑스 와이 그다음에 엑스 익스클루시브 오어 와이',
             '그래서 익스클루시브 오어를 어떻게 구현하느냐 엔드오아로',
             '여기까지 따라온 사람 손 들어보세요',
             '잘들 따라오고 있죠? 아직까지는 어려운 거 없어요',
             '집중 안하고 있죠 아침 월요일 아침이라 로그인만 해놓고 자는 거',
             '얘 둘도 낸드가 돼요 근데 문제는 이쪽 파시 포션이죠',
             '력은 뭐가 돼요 우리 저 손들고 학생 있는 학생 손 내리고',
             '이승주 학생도 아직 손 들고 있는데 손 내리고 김용재 김은솔 이선주',
             '돌아왔으면 손 들어보세요 정신차렸으면 손 손 들어보세요',
             '요 회로가 이거랑 똑같',
             '까지 이해한 사람 손 들어보세요. 아 여기는 그냥 앤드 오어니깐 여기 위랑 익스',
             '에 액스 바 플러스 와이 바 플러스',
             '으 이렇게 되겠지. 액스 바 플러스 와이 바에',
             '에 와이가 되죠? 여기까지 따라온 사람 손 내리고',
             '자 손 아직 안 든 사람 김은솔 학생',
             '랑 이 친구는 내가 뭘 보낼 수 있나',
             '해야지 여기는 자꾸 다른 짓 하는 건지 모르겠네',
             '집중 안하면 안되겠죠?',
             '랑 자기 자신을 익스클루시브 오어 하면',
             '오어 하면 이 전체의 와이 바 한 거랑 같다',
             '액스 바 와이가 되죠. 익스클루',
             '그래서 얘랑 얘랑 캔슬 캔슬되고 결국 액스 와이 플러스 액스 바 와이 바가 돼요',
             '자 지금 이거 설명 이해된 사람 손 들어보세요',
             '이해 되죠? 그 다음에 지금 내가 사실은',
             '맨 처음에 액스가 들어오고 얘를 컴플리먼트하니깐 와이가 되죠 그 다음에',
             '자 이거 설명 이해된 사람 다시 손 내리세요',
             '액스 익스클루시브 와이 컴플리먼트랑 같다. 또 반대로 앞에 거를',
             '그래서 익스클루시브 오어 펑션을 이용하면 이븐 패러티를 생성해줄 수가 있다',
             '그래서 실질적으로 얘는 이븐 패러티라고 부르고 얘는',
             '패러티가 되고 이븐 패러티를 제너레이트하는 펑션 자체는',
             '아 아드 펑션이 되는 거죠 아드 펑션 자',
             '자 여기까지 따라온 사람 손 들어보세요 아 김은',
             '굉장히 적겠죠 굉장히 적으니깐 보통 싱글 비트 에러',
             '근데 만약 얘가 홀수 개면 분명히 이븐 패러티를 저장해',
             '자 아 먼저 어낼리시스',
             '어떤 펑션을 구현 구현한 거예요 분석을 해볼 수가 있어요',
             '그 다음에 계속 여기에 들어오면 요 각각을',
             '수식으로 불린 식으로 표현해보세요',
             '그럼 에이 플러스 비 바에 디가 돼서 얘를 다시 풀어쓰면',
             '이거가 이거가 된 걸 보면 아',
             '불린 식으로하면 이렇게 표현할 수가 있고 이게 이제 최종적으로',
             '우리가 미니마이즈 해줄 수가 있어요 자 이제',
             '아 이게 들어왔을 때는 뭐예요? 지를 빼줬고 나머지는 다 일을',
             '자 이거 이해된 사람 손 들어보세요',
             ]

# %%
root = '../dataset/wav/_d_system_2/'

audio_list = ['segment_15.wav',
              'segment_20.wav',
              'segment_25.wav',
              'segment_16.wav',
              'segment_31.wav',
              'segment_32.wav',
              'segment_40.wav',
              'segment_45.wav',
              'segment_50.wav',
              'segment_51.wav',
              'segment_55.wav',
              'segment_57.wav',
              'segment_60.wav',
              'segment_63.wav',
              'segment_65.wav',
              'segment_67.wav',
              'segment_70.wav',
              'segment_76.wav',
              'segment_81.wav',
              'segment_100.wav',
              'segment_111.wav',
              'segment_115.wav',
              'segment_122.wav',
              'segment_137.wav',
              'segment_150.wav',
              'segment_177.wav',
              'segment_178.wav',
              'segment_181.wav',
              'segment_190.wav',
              'segment_195.wav',
              'segment_246.wav',
              'segment_247.wav',
              ]

text_list = ['그 가정이죠 영은 오어에대한 아이덴티티 앨리먼트',
             '이 존재한다. 그 다음에 이제',
             '택하면 듀오드라는 것은 오어를 앤드로 오어를 앤드로',
             '일은 앤드에 대한 아이덴티티 앨리먼트다. 이게 첫 번째',
             '자 김병준 최우영 학생 따라옵니까?',
             '자 듀오링이 뭐예요? 오어를 앤드로 앤드를 오어로 바꾸고 일을 영으로 영을 일로 바꾸',
             '하지만 등식은 듀올을 택해도 등식은 성립한다는 게 듀얼',
             '볼 수 있어. 이것도 듀얼이고 두 수식은 다르지만 등식은 성립한다',
             '법칙은 다음과 같이 볼 수 있습니다. 그 이것도 증명될 수 있는데 액스',
             '더하기 와이 더하기 이제 와이 더하지 지를 먼저 한 거 하고 액스',
             '랑 와이 액스 오아 와이를 컴플리먼트 한 거는',
             '다 이게 드모르간의 법칙이에요 그리고 이거를 다',
             '앤드한 거를 컴플리먼트한 거는 가껄 컴플리먼트 하고', # 이상함?
             '드모르간의 법칙 생각난다 생각나는 사람 손 들어보세요',
             '한번쯤은 다 배웠을 거예요 드모르간의 법칙',
             '혹시 따라오죠? 김범준 학생 따라오죠?',
             '를 앤드 해봤자 액스 액스 앤 액스도 액스랑 같다고 했죠?',
             '먼저 앞에 거를 먼저 해주나 뒤에 거를 먼저 해주나 상관이 없기 때문에',
             '액스 플러스 와이지 이게 이제 대수랑 헷갈리면 안돼요 둘 다 배분 법칙',
             '또 일을 영 영을 일로 교환해주는 것을 듀얼이라고 하고 요 앞',
             '불린 알제브라의 특성이라고 생각해 보면 됩니다. 자 지금까지 설명 잘 따라온 사람 손 내려보세요',
             '자 그래서 우리가 불린 대수를 이용하면 대수를 이용해서 어떤 디지털 회로를',
             '에이치 더하기 여기 오아가 있으니깐 여기는 얘는 액스 바',
             '수식을 감소할 수 있다. 이해된 사람 손 내려보세요',
             '그래서 실제 회로 설계는 이렇게 하는 게 좋겠죠',
             '따라오겠죠 컴플리먼트 스캔 드모르간의 법칙을 적용해서 앤드를 오아로 오아를 앤',
             '드로 각각은 변수는 컴플리먼트를 취하면 돼요 거기 두 명 손 들고 있는 학생',
             '한데 불린 수식이나 실제 회로도는 여러 개일 수있어 단순화되어 있는 경우도',
             '하는 그런 각 인풋 컴비네이션에 해당하는 민 폼을',
             '테이블을 그리면 컴비네이션 영 영 영부터 일 일 일까지 여덟 빗 인풋 컴비네이션이 존재를 하',
             '딱 하나로 귀결되니깐 어떻게 표준적인 형태고 이러한 표준적인 형태를 우리가',
             '커노니칼 폼이라고 한다 자 지금 케노니칼 폼 이해된 사람 손 내'
             ]

# %%
root = '../dataset/wav/_d_system_3/'

audio_list = ['segment_15.wav',
              'segment_20.wav',
              'segment_25.wav',
              'segment_30.wav',
              'segment_35.wav',
              'segment_50.wav',
              'segment_55.wav',
              'segment_58.wav',
              'segment_62.wav',
              'segment_90.wav',
              'segment_95.wav',
              'segment_100.wav',
              'segment_107.wav',
              'segment_110.wav',
              'segment_115.wav',
              'segment_120.wav',
              'segment_125.wav',
              'segment_130.wav',
              'segment_135.wav',
              'segment_136.wav',
              'segment_140.wav',
              'segment_145.wav',
              ]

text_list = ['요 지금 일일일 세 개가 빠져있죠 그래서 이걸 포함하는 게 제일 큰 게 어떻게 되죠',
             '얘는 액스가 1이고',
             '위에거는 더블유바에',
             '표현이 된다 자 지금 설명 이해되는 사람 손',
             '이렇게 연결되고 이렇게 연결되고 이렇게 연결되니까 이렇게 4개짜리',
             '한 게 가장 큰 게 두개짜리죠 그래서 이렇게 하나가 돼서 얘는',
             '자 여기 가기 전에 하나 더 해볼까요 그러면',
             '엑스 와이 지로 하고 일일일일일 나도 랜덤하게 하는거예요',
             '그 다음에 채팅방에 이것도 꺼놨',
             '와이 지가 되고 이거에 해당하는게 뭐죠 더블유 바',
             '랐네요 임상현 학생 보너스 5점 나한테 이메일 보내세요 자 이거',
             '란 김은솔 학생 다 따라와요 다 따라왔죠 이렇게 미리 맞이할 씁 자',
             '텀의 갯수도 줄이고 앤드 오어 그 수를 줄이고',
             '프라임 임플리컨트 임플리컨트라는 용어가 있고',
             '텀이 임플리컨트다라는 어떤 펑션 임플리컨트다 이런 말은 무슨 말이냐면',
             '컨트고 이것도 임플리컨트예요 즉 임플리컨트라는 것은',
             '자 지금 설명 이해되는 사람 손 내려보세요 자 임플리컨트라는 것은 어떤',
             '임플리컨트라고 한다 여기까지 이해되죠 2명 손 들고 있는데 이해됩니까 따라옵',
             '자 대답이 없죠 스택탑',
             '프라임 임플리컨트란 뭐냐하면 프로덕트 텀이긴 한데',
             '임 임플리컨트에서 어떤 변수 하나 빼게되면',
             '한 개짜리가 네 개 있고 두개 짜리 얘도 얘도 얘도 임플리컨트고 네 개짜린'
             ]

# %% [markdown]
# ### file 확인

# %%
import IPython.display
import os

select_file = -11   # n번째 파일의 text 확인, -1은 마지막 파일
audio_file_path = os.path.join(root, audio_list[select_file])
print(text_list[select_file])
IPython.display.Audio(audio_file_path)
# Out:
# 란 김은솔 학생 다 따라와요 다 따라왔죠 이렇게 미리 맞이할 씁 자
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print('audio 개수 : ', len(audio_list))
print('text 개수 : ', len(text_list))
# Out:
# audio 개수 :  46
# text 개수 :  46

# %%
# 46 + 20

# %%
46 + 32 + 22
# Out:
# 100
